# %%
import pandas as pd
import numpy 
import tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(40,input_dim=4,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(25,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])

# %%
#18년도 데이터로 FITTING
df_18=pd.read_csv("팀투수_2018.csv",parse_dates=['GDAY_DS'])

df_18["T_avg_ER"]=(df_18['ER']*9)/df_18['INN2']
df_18["WHIP"]=(df_18['HIT']+df_18['HR']+df_18['BB'])/df_18['INN2']
del df_18['ER']
del df_18['INN2']

df_18_HT=df_18[df_18['T_ID']=='HT']
df_18_HT=df_18_HT.set_index('GDAY_DS')

#df_18_HT

X_18_HT=df_18_HT[['HIT','WHIP','PA','HR']]
Y_18_HT=df_18_HT['T_avg_ER']

Y_18_HT_sh=Y_18_HT.shift(-29)
#Y_HT_18_sh
model.fit(X_18_HT[:-29],Y_18_HT_sh[:-29],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 115 samples
# Epoch 1/40
# 115/115 [==============================] - 0s 870us/sample - loss: 4.7483 - accuracy: 0.0348
# Epoch 2/40
# 115/115 [==============================] - 0s 96us/sample - loss: 4.2831 - accuracy: 0.0348
# Epoch 3/40
# 115/115 [==============================] - 0s 69us/sample - loss: 3.5727 - accuracy: 0.0261
# Epoch 4/40
# 115/115 [==============================] - 0s 116us/sample - loss: 2.4729 - accuracy: 0.0870
# Epoch 5/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.5272 - accuracy: 0.0870
# Epoch 6/40
# 115/115 [==============================] - 0s 104us/sample - loss: 1.5504 - accuracy: 0.0870
# Epoch 7/40
# 115/115 [==============================] - 0s 104us/sample - loss: 1.5182 - accuracy: 0.0870
# Epoch 8/40
# ...

# %%
#19년도 데이터로 FITTING
df_19=pd.read_csv("팀투수_2019.csv",parse_dates=['GDAY_DS'])

df_19["T_avg_ER"]=(df_19['ER']*9)/df_19['INN2']
df_19["WHIP"]=(df_19['HIT']+df_19['HR']+df_19['BB'])/df_19['INN2']
del df_19['ER']
del df_19['INN2']


df_19_HT=df_19[df_19['T_ID']=='HT']
df_19_HT=df_19_HT.set_index('GDAY_DS')


X_19_HT=df_19_HT[['HIT','WHIP','PA','HR']]
Y_19_HT=df_19_HT['T_avg_ER']

Y_19_HT_sh=Y_19_HT.shift(-29)
#Y_HT_19_sh

model.fit(X_19_HT[:-29],Y_19_HT_sh[:-29],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 115 samples
# Epoch 1/40
# 115/115 [==============================] - 0s 70us/sample - loss: 1.5032 - accuracy: 0.0261
# Epoch 2/40
# 115/115 [==============================] - 0s 82us/sample - loss: 1.4173 - accuracy: 0.0261
# Epoch 3/40
# 115/115 [==============================] - 0s 155us/sample - loss: 1.3758 - accuracy: 0.0261
# Epoch 4/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.3712 - accuracy: 0.0261
# Epoch 5/40
# 115/115 [==============================] - 0s 104us/sample - loss: 1.3847 - accuracy: 0.0261
# Epoch 6/40
# 115/115 [==============================] - 0s 104us/sample - loss: 1.3690 - accuracy: 0.0261
# Epoch 7/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.3721 - accuracy: 0.0261
# Epoch 8/40
# ...

# %%
#20년도 데이터로 FITTING
df_20=pd.read_csv("팀투수_2020.csv",parse_dates=['GDAY_DS'])

df_20["T_avg_ER"]=(df_20['ER']*9)/df_20['INN2']
df_20["WHIP"]=(df_20['HIT']+df_20['HR']+df_20['BB'])/df_20['INN2']
del df_20['ER']
del df_20['INN2']


df_20_HT=df_20[df_20['T_ID']=='HT']
df_20_HT=df_20_HT.set_index('GDAY_DS')


X_20_HT=df_20_HT[['HIT','WHIP','PA','HR']]
Y_20_HT=df_20_HT['T_avg_ER']

Y_20_HT_sh=Y_20_HT.shift(-29)
#Y_HT_20_sh

model.fit(X_20_HT[:-29],Y_20_HT_sh[:-29],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 33 samples
# Epoch 1/40
# 33/33 [==============================] - 0s 121us/sample - loss: 1.1181 - accuracy: 0.1818
# Epoch 2/40
# 33/33 [==============================] - 0s 121us/sample - loss: 1.1147 - accuracy: 0.1818
# Epoch 3/40
# 33/33 [==============================] - 0s 182us/sample - loss: 1.1126 - accuracy: 0.1818
# Epoch 4/40
# 33/33 [==============================] - 0s 151us/sample - loss: 1.1067 - accuracy: 0.1818
# Epoch 5/40
# 33/33 [==============================] - 0s 152us/sample - loss: 1.1136 - accuracy: 0.1818
# Epoch 6/40
# 33/33 [==============================] - 0s 151us/sample - loss: 1.1164 - accuracy: 0.1818
# Epoch 7/40
# 33/33 [==============================] - 0s 122us/sample - loss: 1.1267 - accuracy: 0.1818
# Epoch 8/40
# ...

# %%
#예측값 구하기
test_20=pd.read_csv('2020투수기록.csv')

test_20_HT=test_20[test_20['T_ID']=='HT']

test_input_HT=test_20_HT[['HIT','WHIP','PA','HR']]

HT_prediction_20=model.predict(test_input_HT[-29:]).flatten()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
HT_prediction_20
# Out:
# array([1.6436865, 1.7722709, 2.0238454, 1.678127 , 1.4987106, 1.6087248,
#        1.8086188, 1.6914597, 1.7313933, 1.7259339, 1.8067954, 1.2645804,
#        1.3204566, 1.4358132, 1.4727104, 1.4977789, 1.6549268, 1.6003184,
#        1.4170333, 1.5639017, 2.0751529, 1.7160386, 1.4278184, 1.5365945,
#        1.2413925, 1.9615638, 1.3930486, 1.9463991, 1.4329005],
#       dtype=float32)
