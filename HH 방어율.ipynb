# %%
import pandas as pd
import numpy 
import tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(40,input_dim=4,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(25,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])

# %%
#18년도 데이터로 FITTING
df_18=pd.read_csv("팀투수_2018.csv",parse_dates=['GDAY_DS'])

df_18["T_avg_ER"]=(df_18['ER']*9)/df_18['INN2']
df_18["WHIP"]=(df_18['HIT']+df_18['HR']+df_18['BB'])/df_18['INN2']
del df_18['ER']
del df_18['INN2']

df_18_HH=df_18[df_18['T_ID']=='HH']
df_18_HH=df_18_HH.set_index('GDAY_DS')

#df_18_HH

X_18_HH=df_18_HH[['HIT','WHIP','PA','HR']]
Y_18_HH=df_18_HH['T_avg_ER']

Y_18_HH_sh=Y_18_HH.shift(-29)
#Y_HH_18_sh
model.fit(X_18_HH[:-29],Y_18_HH_sh[:-29],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 115 samples
# Epoch 1/40
# 115/115 [==============================] - 0s 683us/sample - loss: 1.5791 - accuracy: 0.1304
# Epoch 2/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.4868 - accuracy: 0.1304
# Epoch 3/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.4696 - accuracy: 0.1304
# Epoch 4/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.4528 - accuracy: 0.1304
# Epoch 5/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.4385 - accuracy: 0.1304
# Epoch 6/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.4372 - accuracy: 0.1304
# Epoch 7/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.4089 - accuracy: 0.1304
# Epoch 8/40
# ...

# %%
#19년도 데이터로 FITTING
df_19=pd.read_csv("팀투수_2019.csv",parse_dates=['GDAY_DS'])

df_19["T_avg_ER"]=(df_19['ER']*9)/df_19['INN2']
df_19["WHIP"]=(df_19['HIT']+df_19['HR']+df_19['BB'])/df_19['INN2']
del df_19['ER']
del df_19['INN2']


df_19_HH=df_19[df_19['T_ID']=='HH']
df_19_HH=df_19_HH.set_index('GDAY_DS')


X_19_HH=df_19_HH[['HIT','WHIP','PA','HR']]
Y_19_HH=df_19_HH['T_avg_ER']

Y_19_HH_sh=Y_19_HH.shift(-29)
#Y_HH_19_sh

model.fit(X_19_HH[:-29],Y_19_HH_sh[:-29],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 115 samples
# Epoch 1/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.5444 - accuracy: 0.1130
# Epoch 2/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.5136 - accuracy: 0.1130
# Epoch 3/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.4378 - accuracy: 0.1130
# Epoch 4/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.4814 - accuracy: 0.1130
# Epoch 5/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.4644 - accuracy: 0.1130
# Epoch 6/40
# 115/115 [==============================] - 0s 96us/sample - loss: 1.4524 - accuracy: 0.1130
# Epoch 7/40
# 115/115 [==============================] - 0s 87us/sample - loss: 1.4529 - accuracy: 0.1130
# Epoch 8/40
# ...

# %%
#20년도 데이터로 FITTING
df_20=pd.read_csv("팀투수_2020.csv",parse_dates=['GDAY_DS'])

df_20["T_avg_ER"]=(df_20['ER']*9)/df_20['INN2']
df_20["WHIP"]=(df_20['HIT']+df_20['HR']+df_20['BB'])/df_20['INN2']
del df_20['ER']
del df_20['INN2']


df_20_HH=df_20[df_20['T_ID']=='HH']
df_20_HH=df_20_HH.set_index('GDAY_DS')


X_20_HH=df_20_HH[['HIT','WHIP','PA','HR']]
Y_20_HH=df_20_HH['T_avg_ER']

Y_20_HH_sh=Y_20_HH.shift(-29)
#Y_HH_20_sh

model.fit(X_20_HH[:-29],Y_20_HH_sh[:-29],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 36 samples
# Epoch 1/40
# 36/36 [==============================] - 0s 111us/sample - loss: 0.9528 - accuracy: 0.0278
# Epoch 2/40
# 36/36 [==============================] - 0s 111us/sample - loss: 0.9317 - accuracy: 0.0278
# Epoch 3/40
# 36/36 [==============================] - 0s 139us/sample - loss: 0.9139 - accuracy: 0.0278
# Epoch 4/40
# 36/36 [==============================] - 0s 111us/sample - loss: 0.9006 - accuracy: 0.0278
# Epoch 5/40
# 36/36 [==============================] - 0s 139us/sample - loss: 0.8887 - accuracy: 0.0278
# Epoch 6/40
# 36/36 [==============================] - 0s 139us/sample - loss: 0.8941 - accuracy: 0.0278
# Epoch 7/40
# 36/36 [==============================] - 0s 139us/sample - loss: 0.8779 - accuracy: 0.0278
# Epoch 8/40
# ...

# %%
#예측값 구하기
test_20=pd.read_csv('2020투수기록.csv')

test_20_HH=test_20[test_20['T_ID']=='HH']

test_input_HH=test_20_HH[['HIT','WHIP','PA','HR']]

HH_prediction_20=model.predict(test_input_HH[-29:]).flatten()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
HH_prediction_20
# Out:
# array([1.4860532, 1.3997303, 1.5522885, 1.5188313, 1.5436851, 1.6702337,
#        1.489782 , 1.6004127, 1.6327064, 1.6017349, 1.6726872, 1.5232912,
#        1.8729458, 1.7207808, 1.6552098, 1.515242 , 1.7003621, 1.5731235,
#        1.6510733, 1.7111132, 1.6997312, 1.9529853, 1.4413795, 1.4082975,
#        1.5724554, 1.6170204, 1.4078053, 1.8240012, 1.5758116],
#       dtype=float32)
