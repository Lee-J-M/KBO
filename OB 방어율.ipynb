# %%
import pandas as pd
import numpy 
import tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
model=Sequential()
model.add(Dense(40,input_dim=4,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(25,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])
#model.summary()

# %%
#18년도 데이터로 FITTING
df_18=pd.read_csv("팀투수_2018.csv",parse_dates=['GDAY_DS'])

df_18["T_avg_ER"]=(df_18['ER']*9)/df_18['INN2']
df_18["WHIP"]=(df_18['HIT']+df_18['HR']+df_18['BB'])/df_18['INN2']
del df_18['ER']
del df_18['INN2']

df_18_OB=df_18[df_18['T_ID']=='OB']
df_18_OB=df_18_OB.set_index('GDAY_DS')

X_OB_18=df_18_OB[['HIT','WHIP','PA','HR']]
Y_OB_18=df_18_OB['T_avg_ER']

Y_OB_18_sh=Y_OB_18.shift(-28)
#Y_OB_19_sh

model.fit(X_OB_18[:-28],Y_OB_18_sh[:-28],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 116 samples
# Epoch 1/40
# 116/116 [==============================] - 0s 680us/sample - loss: 4.6422 - accuracy: 0.0776
# Epoch 2/40
# 116/116 [==============================] - 0s 86us/sample - loss: 3.4929 - accuracy: 0.1034
# Epoch 3/40
# 116/116 [==============================] - 0s 95us/sample - loss: 2.1717 - accuracy: 0.1207
# Epoch 4/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.9512 - accuracy: 0.1207
# Epoch 5/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.8518 - accuracy: 0.1207
# Epoch 6/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.9142 - accuracy: 0.1207
# Epoch 7/40
# 116/116 [==============================] - 0s 95us/sample - loss: 1.8659 - accuracy: 0.1207
# Epoch 8/40
# ...

# %%
#19년도 데이터로 FITTING
df_19=pd.read_csv("팀투수_2019.csv",parse_dates=['GDAY_DS'])

df_19["T_avg_ER"]=(df_19['ER']*9)/df_19['INN2']
df_19["WHIP"]=(df_19['HIT']+df_19['HR']+df_19['BB'])/df_19['INN2']
del df_19['ER']
del df_19['INN2']

df_19_OB=df_19[df_19['T_ID']=='OB']
df_19_OB=df_19_OB.set_index('GDAY_DS')

X_OB_19=df_19_OB[['HIT','WHIP','PA','HR']]
Y_OB_19=df_19_OB['T_avg_ER']

Y_OB_19_sh=Y_OB_19.shift(-28)
#Y_OB_19_sh

model.fit(X_OB_19[:-28],Y_OB_19_sh[:-28],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 116 samples
# Epoch 1/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.2826 - accuracy: 0.1034
# Epoch 2/40
# 116/116 [==============================] - 0s 95us/sample - loss: 1.1998 - accuracy: 0.1034
# Epoch 3/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.2369 - accuracy: 0.1034
# Epoch 4/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.1817 - accuracy: 0.1034
# Epoch 5/40
# 116/116 [==============================] - 0s 95us/sample - loss: 1.2026 - accuracy: 0.1034
# Epoch 6/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.1838 - accuracy: 0.1034
# Epoch 7/40
# 116/116 [==============================] - 0s 86us/sample - loss: 1.1827 - accuracy: 0.1034
# Epoch 8/40
# ...

# %%
#20년도 데이터로 FITTING
df_20=pd.read_csv("팀투수_2020.csv",parse_dates=['GDAY_DS'])

df_20["T_avg_ER"]=(df_20['ER']*9)/df_20['INN2']
df_20["WHIP"]=(df_20['HIT']+df_20['HR']+df_20['BB'])/df_20['INN2']
del df_20['ER']
del df_20['INN2']


df_20_OB=df_20[df_20['T_ID']=='OB']
df_20_OB=df_20_OB.set_index('GDAY_DS')


X_20_OB=df_20_OB[['HIT','WHIP','PA','HR']]
Y_20_OB=df_20_OB['T_avg_ER']

Y_20_OB_sh=Y_20_OB.shift(-28)
#Y_OB_19_sh

model.fit(X_20_OB[:-28],Y_20_OB_sh[:-28],epochs=40,batch_size=10)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 36 samples
# Epoch 1/40
# 36/36 [==============================] - 0s 111us/sample - loss: 1.4436 - accuracy: 0.0833
# Epoch 2/40
# 36/36 [==============================] - 0s 121us/sample - loss: 1.4184 - accuracy: 0.0833
# Epoch 3/40
# 36/36 [==============================] - 0s 139us/sample - loss: 1.4101 - accuracy: 0.0833
# Epoch 4/40
# 36/36 [==============================] - 0s 138us/sample - loss: 1.3730 - accuracy: 0.0833
# Epoch 5/40
# 36/36 [==============================] - 0s 111us/sample - loss: 1.3742 - accuracy: 0.0833
# Epoch 6/40
# 36/36 [==============================] - 0s 139us/sample - loss: 1.3672 - accuracy: 0.0833
# Epoch 7/40
# 36/36 [==============================] - 0s 111us/sample - loss: 1.3675 - accuracy: 0.0833
# Epoch 8/40
# ...

# %%
#예측값 구하기
test_20=pd.read_csv('2020투수기록.csv')

test_20_OB=test_20[test_20['T_ID']=='OB']

test_input_OB=test_20_OB[['HIT','WHIP','PA','HR']]

OB_prediction_20=model.predict(test_input_OB[-28:]).flatten()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
OB_prediction_20
# Out:
# array([1.7571847, 1.6632607, 1.4395005, 1.5380179, 1.5380179, 1.4478287,
#        1.4734064, 1.2667327, 1.3501222, 1.5817491, 1.3335198, 1.3335198,
#        1.3335198, 1.4111155, 1.5515686, 1.7220984, 1.4705414, 1.4797318,
#        2.341647 , 1.5211406, 1.5309154, 1.4457346, 1.7601589, 1.4852037,
#        1.4478287, 1.4225894, 1.4042513, 1.4297357], dtype=float32)
